# %% [markdown]
# ## Matplotlib Tutorial

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
mpl.get_backend()
# Out:
# 'nbAgg'

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
plt.plot(3,2)
# Out:
# <img src="data:image/png;base64,..." width="640">
